# %%
######3 what is curse of dimensionality 



# in ml we do have features 


# curse of dimensionality is also called curse of features

# three is a optimal no of featurers and after those features out model will not 
# work as intended 
# if we have all those features from the data so more computition will be waste and model performance will be same or even reduce
# most of the time you have high dimension of data so what you need to do for higher dimension 
# there will be sparsity 
# - certatinity about feature need to be there 
# in one dimension you will able to find data point fast rather then 2 dimenion plane in real life

# %%
# we will take subset of features to get the data and train out out model
