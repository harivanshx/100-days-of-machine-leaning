# %% [markdown]
# ## Using data from the api and converting it to the dataframe

# %% [markdown]
# have to think which columns we want so that we get to know which info is relevent in the data frame from the api
# and after doing so we will get the dataframe for just one page but we can increase the parameter and then append the data
# in the data frame
