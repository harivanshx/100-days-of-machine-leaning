# %%
pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.17.0-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (2.10.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (2.1.3)
# Collecting minify-html>=0.15.0 (from ydata-profiling)
#   Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (0.14.4)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling)
#   Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in c:\users\hariv\anaconda3\lib\site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in c:\users\hariv\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in c:\users\hariv\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hariv\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\hariv\anaconda3\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hariv\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hariv\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\hariv\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hariv\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hariv\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hariv\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hariv\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\hariv\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\hariv\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Collecting typing_extensions>=4.14.0 (from typeguard<5,>=3->ydata-profiling)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\hariv\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\hariv\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hariv\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\hariv\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\hariv\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.17.0-py2.py3-none-any.whl (399 kB)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    --------------------------------------- 678.1/678.1 kB 27.8 MB/s eta 0:00:00
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 3.1/3.1 MB 35.0 MB/s eta 0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl (300 kB)
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
# Installing collected packages: puremagic, minify-html, filetype, typing_extensions, multimethod, dacite, typeguard, imagehash, wordcloud, visions, phik, ydata-profiling
#
#    ------ ---------------------------------  2/12 [filetype]
#   Attempting uninstall: typing_extensions
#    ------ ---------------------------------  2/12 [filetype]
#     Found existing installation: typing_extensions 4.12.2
#    ------ ---------------------------------  2/12 [filetype]
#     Uninstalling typing_extensions-4.12.2:
#    ------ ---------------------------------  2/12 [filetype]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------- -----------------------------  3/12 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ---------- -----------------------------  3/12 [typing_extensions]
#    ---------------- -----------------------  5/12 [dacite]
#    ----------------------- ----------------  7/12 [imagehash]
#    ------------------------------ ---------  9/12 [visions]
#    ------------------------------ ---------  9/12 [visions]
#    ------------------------------ ---------  9/12 [visions]
#    ------------------------------ ---------  9/12 [visions]
#    ------------------------------------ --- 11/12 [ydata-profiling]
#    ------------------------------------ --- 11/12 [ydata-profiling]
#    ------------------------------------ --- 11/12 [ydata-profiling]
#    ------------------------------------ --- 11/12 [ydata-profiling]
#    ------------------------------------ --- 11/12 [ydata-profiling]
#    ------------------------------------ --- 11/12 [ydata-profiling]
#    ---------------------------------------- 12/12 [ydata-profiling]
#
# Successfully installed dacite-1.9.2 filetype-1.2.0 imagehash-4.3.1 minify-html-0.18.1 multimethod-1.12 phik-0.12.5 puremagic-1.30 typeguard-4.4.4 typing_extensions-4.15.0 visions-0.8.1 wordcloud-1.9.4 ydata-profiling-4.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import seaborn as sns
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
df = pd.read_csv('train.csv')

prof = ProfileReport(df)

# %%
prof.to_file("report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 151.90it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install legacy-cgi
# then retry installing pandas_profiling
# !pip install pandas_profiling
# Out:
# Collecting legacy-cgi
#   Downloading legacy_cgi-2.6.4-py3-none-any.whl.metadata (2.3 kB)
# Downloading legacy_cgi-2.6.4-py3-none-any.whl (20 kB)
# Installing collected packages: legacy-cgi
# Successfully installed legacy-cgi-2.6.4
# Collecting pandas_profiling
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas_profiling)
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (2.2.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (3.10.0)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (2.10.3)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (6.0.2)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (3.1.6)
# Collecting markupsafe~=2.1.1 (from pandas_profiling)
#   Using cached MarkupSafe-2.1.5.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas_profiling)
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (2.1.3)
# Collecting htmlmin>=0.1.12 (from pandas_profiling)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas_profiling)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: phik>=0.11.1 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (0.12.5)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas_profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (2.32.3)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (4.67.1)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\hariv\anaconda3\lib\site-packages (from pandas_profiling) (1.12)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\hariv\anaconda3\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas_profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\hariv\anaconda3\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas_profiling) (3.4.2)
# Requirement already satisfied: imagehash in c:\users\hariv\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\hariv\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hariv\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hariv\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hariv\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hariv\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas_profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\hariv\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas_profiling) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\hariv\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas_profiling) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\hariv\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas_profiling) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hariv\anaconda3\lib\site-packages (from requests>=2.24.0->pandas_profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hariv\anaconda3\lib\site-packages (from requests>=2.24.0->pandas_profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hariv\anaconda3\lib\site-packages (from requests>=2.24.0->pandas_profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hariv\anaconda3\lib\site-packages (from requests>=2.24.0->pandas_profiling) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\hariv\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas_profiling) (0.4.6)
# Requirement already satisfied: PyWavelets in c:\users\hariv\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas_profiling) (1.8.0)
# Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 4.7/4.7 MB 40.7 MB/s eta 0:00:00
# Downloading visions-0.7.4-py3-none-any.whl (102 kB)
# Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Building wheels for collected packages: markupsafe, htmlmin
#   Building wheel for markupsafe (setup.py): started
#   Building wheel for markupsafe (setup.py): finished with status 'done'
#   Created wheel for markupsafe: filename=MarkupSafe-2.1.5-py3-none-any.whl size=9912 sha256=563745fa53712c2c99b15045782c3705a4638c62a4a933510a129e4ebfd0995a
#   Stored in directory: c:\users\hariv\appdata\local\pip\cache\wheels\c2\0c\c0\d6d953ac80cacc2dd1d329d675c67d1e7775bad02a8faedef0
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27092 sha256=eb582434494fb81d5e6a50a76f2e122312ce7a712fee2936a76e6516ba15532b
#   Stored in directory: c:\users\hariv\appdata\local\pip\cache\wheels\f3\2e\77\69db90d4b1c24cc4f1f7fce293d32ba65c823db3bac99afd61
# Successfully built markupsafe htmlmin
# Installing collected packages: htmlmin, tangled-up-in-unicode, markupsafe, joblib, visions, missingno, pandas_profiling
#
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#   Attempting uninstall: markupsafe
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#     Found existing installation: MarkupSafe 3.0.2
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#     Uninstalling MarkupSafe-3.0.2:
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#       Successfully uninstalled MarkupSafe-3.0.2
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#   Attempting uninstall: joblib
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#     Found existing installation: joblib 1.4.2
#    ----- ---------------------------------- 1/7 [tangled-up-in-unicode]
#    ----------------- ---------------------- 3/7 [joblib]
#     Uninstalling joblib-1.4.2:
#    ----------------- ---------------------- 3/7 [joblib]
#       Successfully uninstalled joblib-1.4.2
#    ----------------- ---------------------- 3/7 [joblib]
#    ----------------- ---------------------- 3/7 [joblib]
#    ----------------- ---------------------- 3/7 [joblib]
#   Attempting uninstall: visions
#    ----------------- ---------------------- 3/7 [joblib]
#     Found existing installation: visions 0.8.1
#    ----------------- ---------------------- 3/7 [joblib]
#    ---------------------- ----------------- 4/7 [visions]
#     Uninstalling visions-0.8.1:
#    ---------------------- ----------------- 4/7 [visions]
#       Successfully uninstalled visions-0.8.1
#    ---------------------- ----------------- 4/7 [visions]
#    ---------------------- ----------------- 4/7 [visions]
#    ---------------------- ----------------- 4/7 [visions]
#    ---------------------- ----------------- 4/7 [visions]
#    ---------------------------------- ----- 6/7 [pandas_profiling]
#    ---------------------------------- ----- 6/7 [pandas_profiling]
#    ---------------------------------------- 7/7 [pandas_profiling]
#
# Successfully installed htmlmin-0.1.12 joblib-1.1.1 markupsafe-2.1.5 missingno-0.5.2 pandas_profiling-3.2.0 tangled-up-in-unicode-0.2.0 visions-0.7.4
#   DEPRECATION: Building 'markupsafe' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'markupsafe'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   DEPRECATION: Building 'htmlmin' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'htmlmin'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.6.1 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.
# ydata-profiling 0.0.dev0 requires visions[type_image_path]<0.8.2,>=0.7.5, but you have visions 0.7.4 which is incompatible.

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pandas_profiling import ProfileReport
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas_profiling\profile_report.py:11
#       9 import yaml
#      10 from tqdm.auto import tqdm
# ---> 11 from visions import VisionsTypeset
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\visions\__init__.py:3
#       1 """Core functionality"""
# ----> 3 from visions import types, typesets, utils
#       4 from visions.backends import *
#       5 from visions.declarative import create_type
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\visions\utils\__init__.py:4
#       1 """ Utilities suite for visions """
#       3 # from visions.utils.images import image_utils
# ----> 4 from visions.utils.monkeypatches import imghdr_patch, pathlib_patch
#       5 from visions.utils.profiling import profile_type
#       6 from visions.utils.warning_handling import suppress_warnings
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\visions\utils\monkeypatches\__init__.py:1
# ----> 1 from visions.utils.monkeypatches import imghdr_patch, pathlib_patch
#       3 __all__ = [
#       4     "imghdr_patch",
#       5     "pathlib_patch",
#       6 ]
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\visions\utils\monkeypatches\imghdr_patch.py:2
#       1 # Monkeypatch bug in imagehdr
# ----> 2 from imghdr import tests
#       5 def test_jpeg1(h, f):
#       6     """JPEG data in JFIF format"""
#
# ModuleNotFoundError: No module named 'imghdr'
