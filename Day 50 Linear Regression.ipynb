# %% [markdown]
# There are three different type of linear regression
# - Simple - one input and one output
# -

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
cgpa = np.array([6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5])
package = np.array([3, 4, 4.5, 5, 6, 7.5, 9, 12])  # in LPA or INR (Lakhs per annum)

df = pd.DataFrame({"CGPA": cgpa, "Package (LPA)": package})
print(df)
# Out:
#    CGPA  Package (LPA)
# 0   6.0            3.0
# 1   6.5            4.0
# 2   7.0            4.5
# 3   7.5            5.0
# 4   8.0            6.0
# 5   8.5            7.5
# 6   9.0            9.0
# 7   9.5           12.0

# %%
X = cgpa.reshape(-1, 1)      # independent variable
y = package                  # dependent variable

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Intercept:", model.intercept_)
print("Slope:", model.coef_[0])
# Out:
# Intercept: -11.708333333333332
# Slope: 2.333333333333333

# %%
cgpa_input = 8.7
prediction = model.predict([[cgpa_input]])
print(f"Predicted Package for CGPA {cgpa_input}: {prediction[0]:.2f} LPA")
# Out:
# Predicted Package for CGPA 8.7: 8.59 LPA

# %%
plt.scatter(cgpa, package, label="Actual Data")
plt.plot(cgpa, model.predict(X), label="Best Fit Line")
plt.xlabel("CGPA")
plt.ylabel("Package (LPA)")
plt.title("CGPA vs Package - Simple Linear Regression")
plt.legend()
plt.show()

# %%
### Now we do multiple linear regression with more features

import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv('cars.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1753242559.py in <cell line: 0>()
#       3 import pandas as pd
#       4 from sklearn.model_selection import train_test_split
# ----> 5 df = pd.read_csv('cars.csv')
#
# ...

# %%
df.head()
# Out:
#    CGPA  Package (LPA)
# 0   6.0            3.0
# 1   6.5            4.0
# 2   7.0            4.5
# 3   7.5            5.0
# 4   8.0            6.0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4058002314.py in <cell line: 0>()
# ----> 1 f
#
# NameError: name 'f' is not defined

# %%
############################### predicting pizza price ##############


import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# step 1 Data collection 

data = {
    "size": [8, 10, 12, 14, 16, 10, 12, 14, 8, 16],
    "toppings_count": [1, 2, 3, 4, 5, 2, 3, 4, 1, 5],
    "cheese_level": [1, 2, 2, 3, 3, 2, 3, 3, 1, 3],
    "crust_type": [0, 1, 1, 2, 2, 0, 1, 2, 0, 2],
    "is_veg": [1, 1, 0, 0, 0, 1, 1, 0, 1, 0],
    "price": [150, 220, 300, 420, 550, 240, 320, 480, 160, 580]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    size  toppings_count  cheese_level  crust_type  is_veg  price
# 0     8               1             1           0       1    150
# 1    10               2             2           1       1    220
# 2    12               3             2           1       0    300
# 3    14               4             3           2       0    420
# 4    16               5             3           2       0    550
# 5    10               2             2           0       1    240
# 6    12               3             3           1       1    320
# 7    14               4             3           2       0    480
# 8     8               1             1           0       1    160
# 9    16               5             3           2       0    580

# %%
df.plot(x='size', y= 'price' , style= 'o')
plt.title('price vs size')
plt.xlabel("Size")
plt.ylabel("Price")
plt.show()

# %%
X = df[["size"]]   # DataFrame → 2D
y = df["price"]

# %%
X
# Out:
# 0     8
# 1    10
# 2    12
# 3    14
# 4    16
# 5    10
# 6    12
# 7    14
# 8     8
# 9    16
# Name: size, dtype: int64

# %%
y
# Out:
# 0    150
# 1    220
# 2    300
# 3    420
# 4    550
# 5    240
# 6    320
# 7    480
# 8    160
# 9    580
# Name: price, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
df.dtypes
# Out:
# size              int64
# toppings_count    int64
# cheese_level      int64
# crust_type        int64
# is_veg            int64
# price             int64
# dtype: object

# %%
Model = LinearRegression()
Model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 Model = LinearRegression()
# ----> 2 Model.fit(X_train,y_train)
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:601, in LinearRegression.fit(self, X, y, sample_weight)
#     597 n_jobs_ = self.n_jobs
#     599 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 601 X, y = validate_data(
#     602     self,
#     603     X,
# ...

# %%
y_pred = Model.predict(X_test)

# %%
y_test
# Out:
# array([[14,  4,  3,  2,  0],
#        [ 8,  1,  1,  0,  1]])

# %%
y_pred
# Out:
# array([[1.40000000e+01, 4.00000000e+00, 3.00000000e+00, 2.00000000e+00,
#         2.37293755e-16],
#        [8.00000000e+00, 1.00000000e+00, 1.00000000e+00, 6.49646578e-16,
#         1.00000000e+00]])

# %%
mean_size = df['size'].mean()

# %%
mean_price = df['price'].mean()

# %%
df["price_deviation"] = df["price"] - df["price"].mean()
df
# Out:
#    size  toppings_count  cheese_level  crust_type  is_veg  price  \
# 0     8               1             1           0       1    150
# 1    10               2             2           1       1    220
# 2    12               3             2           1       0    300
# 3    14               4             3           2       0    420
# 4    16               5             3           2       0    550
# 5    10               2             2           0       1    240
# 6    12               3             3           1       1    320
# 7    14               4             3           2       0    480
# 8     8               1             1           0       1    160
# 9    16               5             3           2       0    580
#
#    price_deviation
# 0           -192.0
# 1           -122.0
# 2            -42.0
# 3             78.0
# 4            208.0
# 5           -102.0
# 6            -22.0
# 7            138.0
# 8           -182.0
# 9            238.0

# %%
df["size_deviation"] = df["size"] - df["size"].mean()
df
# Out:
#    size  toppings_count  cheese_level  crust_type  is_veg  price  \
# 0     8               1             1           0       1    150
# 1    10               2             2           1       1    220
# 2    12               3             2           1       0    300
# 3    14               4             3           2       0    420
# 4    16               5             3           2       0    550
# 5    10               2             2           0       1    240
# 6    12               3             3           1       1    320
# 7    14               4             3           2       0    480
# 8     8               1             1           0       1    160
# 9    16               5             3           2       0    580
#
#    price_deviation  size_deviation
# 0           -192.0            -4.0
# 1           -122.0            -2.0
# 2            -42.0             0.0
# 3             78.0             2.0
# 4            208.0             4.0
# ...

# %%
df['product_deviation'] = df['size_deviation'] * df['price_deviation']

# %%
df['product_deviation']
# Out:
# 0    768.0
# 1    244.0
# 2     -0.0
# 3    156.0
# 4    832.0
# 5    204.0
# 6     -0.0
# 7    276.0
# 8    728.0
# 9    952.0
# Name: product_deviation, dtype: float64

# %%
sum_of_prod_dev = df['product_deviation'].sum()

# %%
sum_of_prod_dev
# Out:
# np.float64(4160.0)

# %%
df['square_dev_size'] = df['size_deviation']**2

# %%
sum_sq_dev_size = df['square_dev_size'].sum()

# %%
m = sum_of_prod_dev/sum_sq_dev_size

# %%
m
# Out:
# np.float64(52.0)

# %%
c = mean_price - (m * mean_size)
c
# Out:
# np.float64(-282.0)

# %%
mse = (df["error"] ** 2).mean()
mse
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'error'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 mse = (df["error"] ** 2).mean()
#       2 mse
#
# ...
